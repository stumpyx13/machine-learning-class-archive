# %%
run hw3_resources/make_dataset.py
# Out:
# Making artist dataset and saving it to: hw3_resources/art_data/
# To change this and other settings, edit the flags at the top of this file.
# Loading images for artist paul_sandby
# Artist dataset size: (36, 50, 50, 3)
# Mean: 96.3834
# Standard deviation: 69.1953
#
# Loading images for artist richard_wilson
# Artist dataset size: (23, 50, 50, 3)
# Mean: 74.8172
# Standard deviation: 67.5412
#
# Loading images for artist canaletto
# Artist dataset size: (20, 50, 50, 3)
# Mean: 81.64
# Standard deviation: 72.5214
#
# Loading images for artist paul_gauguin
# Artist dataset size: (37, 50, 50, 3)
# Mean: 76.4857
# Standard deviation: 59.6516
#
# Loading images for artist claude_monet
# Artist dataset size: (54, 50, 50, 3)
# Mean: 104.037
# Standard deviation: 65.7009
#
# Loading images for artist paul_cezanne
# Artist dataset size: (40, 50, 50, 3)
# Mean: 83.7367
# Standard deviation: 59.4462
#
# Loading images for artist jmw_turner
# Artist dataset size: (70, 50, 50, 3)
# ...

# %%
from hw3_resources import conv

CNN = conv.ArtistConvNet()
# Out:
# /anaconda3/envs/tensorflow/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)
# Loading datasets...
# Training set (364, 50, 50, 3) (364, 11)
# Validation set (87, 50, 50, 3) (87, 11)
# INFO:tensorflow:Scale of 0 disables regularizer.

# %%
CNN.train_model()
# Out:
# Initializing variables...
#
# Batch loss at step 0: 2.378040
# Batch training accuracy: 0.0%
# Full training accuracy: 8.8%
# Validation accuracy: 8.0%
#
# Batch loss at step 100: 1.823610
# Batch training accuracy: 30.0%
# Full training accuracy: 43.4%
# Validation accuracy: 40.2%
#
# Batch loss at step 200: 1.513683
# Batch training accuracy: 30.0%
# Full training accuracy: 47.5%
# Validation accuracy: 39.1%
#
# Batch loss at step 300: 1.310099
# Batch training accuracy: 40.0%
# Full training accuracy: 58.8%
# Validation accuracy: 47.1%
#
# Batch loss at step 400: 0.756108
# Batch training accuracy: 80.0%
# Full training accuracy: 60.4%
# Validation accuracy: 48.3%
#
# Batch loss at step 500: 1.011438
# Batch training accuracy: 70.0%
# Full training accuracy: 70.9%
# Validation accuracy: 51.7%
#
# Batch loss at step 600: 0.952218
# Batch training accuracy: 70.0%
# Full training accuracy: 74.7%
# Validation accuracy: 55.2%
#
# Batch loss at step 700: 0.441249
# ...

# %%
run hw3_resources/conv.py invariance
# Out:
# Testing finished model on invariance datasets!
# Loading datasets...
# Training set (364, 50, 50, 3) (364, 11)
# Validation set (87, 50, 50, 3) (87, 11)
# INFO:tensorflow:Scale of 0 disables regularizer.
# Pool layer 1 activated..
# Initializing variables...
#
# Batch loss at step 0: 2.414863
# Batch training accuracy: 0.0%
# Full training accuracy: 10.4%
# Validation accuracy: 4.6%
#
# Batch loss at step 100: 2.257524
# Batch training accuracy: 10.0%
# Full training accuracy: 20.9%
# Validation accuracy: 19.5%
#
# Batch loss at step 200: 1.720442
# Batch training accuracy: 30.0%
# Full training accuracy: 42.0%
# Validation accuracy: 40.2%
#
# Batch loss at step 300: 1.757922
# Batch training accuracy: 30.0%
# Full training accuracy: 45.9%
# Validation accuracy: 50.6%
#
# Batch loss at step 400: 1.178385
# Batch training accuracy: 60.0%
# Full training accuracy: 53.6%
# Validation accuracy: 49.4%
#
# Batch loss at step 500: 1.443191
# Batch training accuracy: 30.0%
# ...
